# %%
import pandas as pd
import numpy as np

# %%
pd.load_csv('Movimientos_Facturas.csv', sep=';', encoding='latin')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [2], in <cell line: 1>()
# ----> 1 pd.load_csv('Movimientos_Facturas.csv', sep=';', encoding='latin')
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/__init__.py:261, in __getattr__(name)
#     257     from pandas.core.arrays.sparse import SparseArray as _SparseArray
#     259     return _SparseArray
# --> 261 raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#
# AttributeError: module 'pandas' has no attribute 'load_csv'

# %%
pd.read_csv('Movimientos_Facturas.csv', sep=';', encoding='latin')
# Out:
#      Factura_Ser_Ejer_Num Num_Pedido Pedido_Ser_Ejer_Num       Fecha  \
# 0          09-PM/22-01433       1976   01/09-PM/22-01976  21/11/2022
# 1          09-PM/22-01432       1975   01/09-PM/22-01975  21/11/2022
# 2          09-PM/22-01431       1974   01/09-PM/22-01974  21/11/2022
# 3          09-PM/22-01430       1990   01/09-PM/22-01990  21/11/2022
# 4          09-PM/22-01429       1991   01/09-PM/22-01991  21/11/2022
# ...                   ...        ...                 ...         ...
# 3167        08-I/22-00148       3421    01/08-I/22-03421  11/11/2022
# 3168        08-I/22-00131       2900    01/08-I/22-02900   7/10/2022
# 3169        08-I/22-00130       2895    01/08-I/22-02895   7/10/2022
# 3170        08-I/22-00129       2889    01/08-I/22-02889   7/10/2022
# 3171        08-I/22-00147       2336    01/08-I/22-02336  11/11/2022
#
#      Importe_Factura Cantidad Precio  Existencia  Coste Mi Margen  ...  \
# ...

# %%
movimientos = pd.read_csv('Movimientos_Facturas.csv', sep=';', encoding='latin')

# %%
movimientos.dtypes
# Out:
# Factura_Ser_Ejer_Num     object
# Num_Pedido               object
# Pedido_Ser_Ejer_Num      object
# Fecha                    object
# Importe_Factura          object
# Cantidad                 object
# Precio                   object
# Existencia                int64
# Coste                    object
# Mi Margen                object
# Articulo_Referencia      object
# Articulo_Descripcion     object
# Su_pedido                object
# Cod_Delegacion           object
# Hora_Pedido              object
# Peso_Pedido             float64
# Fecha_Pedido             object
# Web                      object
# Cod_Comercial           float64
# Nom_Comercial            object
# Serie_Factura           float64
# Cod_Postal               object
# Nom_Serie_Factura        object
# Cod_Provincia           float64
# Cod_Cliente             float64
# Nomb_Cliente             object
# dtype: object

# %%
actor_name = ('Jose Luis', 'Maria', 'Carlos', 'Scarlet')
actor_age = (34, 18, 50, 42)

# %%
impor pandas as pd
# Out:
#   Input In [7]
#     impor pandas as pd
#           ^
# SyntaxError: invalid syntax

# %%
import pandas as pd

# %%
pd.Series({name:age for name, age in zip(actor_name, actor_age)})
# Out:
# Jose Luis    34
# Maria        18
# Carlos       50
# Scarlet      42
# dtype: int64

# %%
actor_dict = {name:age for name, age in zip(actor_name, actor_age)}

# %%
actor_dict
# Out:
# {'Jose Luis': 34, 'Maria': 18, 'Carlos': 50, 'Scarlet': 42}
